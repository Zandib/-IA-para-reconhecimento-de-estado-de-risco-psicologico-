# %%
import pandas as pd
import numpy as np
from unidecode import unidecode
import matplotlib.pyplot as plt

pd.options.display.max_columns = 999
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from imblearn.over_sampling import SMOTE

from sklearn.ensemble import RandomForestClassifier

import joblib

# %%
import shap

# %% [markdown]
# # Load Data

# %%
base_2018_encoded = pd.read_csv("../data/processed/base_tratada.csv")

# %%
print("Formato do banco de dados",base_2018_encoded.shape)
base_2018_encoded.describe()
# Out:
# Formato do banco de dados (9929, 447)
#        ano_ingresso  frequentou_cursinho  escolaridade_pai  escolaridade_mae  \
# count   9929.000000          1868.000000       1820.000000       1863.000000
# mean    1999.255313             0.881692          6.225824          6.473430
# std      178.014072             0.961178          2.320900          2.151416
# min       -1.000000            -1.000000         -1.000000         -1.000000
# 25%     2013.000000             0.000000          5.000000          6.000000
# 50%     2015.000000             1.000000          6.000000          6.000000
# 75%     2017.000000             2.000000          8.000000          8.000000
# max     2018.000000             2.000000         11.000000         11.000000
#
#        forma_ingresso [Ampla concorrência]  \
# count                          8974.000000
# mean                              0.518944
# std                               0.499669
# min                               0.000000
# 25%                               0.000000
# 50%                               1.000000
# 75%                               1.000000
# max                               1.000000
#
#        forma_ingresso [PEC-G/Transferência Ex Officio/Decisão Judicial]  \
# count                                        4325.000000
# mean                                            0.001850
# std                                             0.042973
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        forma_ingresso [Reserva de vagas (autodeclarado preto, pardo ou indígena)]  \
# count                                        4317.000000
# mean                                            0.262219
# std                                             0.439892
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        forma_ingresso [Reserva de vagas (cursado integralmente o ensino médio em escolas públicas)]  \
# count                                        4317.000000
# mean                                            0.828121
# std                                             0.377319
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        forma_ingresso [Reserva de vagas (pessoa com deficiência)]  \
# count                                        4317.000000
# mean                                            0.027797
# std                                             0.164410
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        forma_ingresso [Reserva de vagas (refugiado ou solicitante de refúgio - incluindo situação de vulnerabilidade econômica)]  \
# count                                        4334.000000
# mean                                            0.003922
# std                                             0.062514
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        forma_ingresso [Reserva de vagas (renda familiar bruta per capita igual ou inferior a 1,5 salário mínimo)]  \
# count                                        4317.000000
# mean                                            0.359741
# std                                             0.479980
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        forma_ingresso [Transferência externa]  \
# count                             4911.000000
# mean                                 0.120953
# std                                  0.326106
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        forma_ingresso [Prefiro não responder]        idade  sexo_biologico  \
# count                             4653.000000  9427.000000     9929.000000
# mean                                 0.072211    23.172483        0.308994
# std                                  0.258866     4.895053        0.511354
# min                                  0.000000    17.000000       -1.000000
# 25%                                  0.000000    20.000000        0.000000
# 50%                                  0.000000    22.000000        0.000000
# 75%                                  0.000000    25.000000        1.000000
# max                                  1.000000    99.000000        1.000000
#
#         nmr_filhos  meio_transporte [Caminhando (percurso total)]  \
# count  9929.000000                                    9556.000000
# mean      0.018733                                       0.132168
# std       0.334751                                       0.338691
# min      -1.000000                                       0.000000
# 25%       0.000000                                       0.000000
# 50%       0.000000                                       0.000000
# 75%       0.000000                                       0.000000
# max       3.000000                                       1.000000
#
#        meio_transporte [Caminhando (parte do percurso)]  \
# count                                       8293.000000
# mean                                           0.171590
# std                                            0.377047
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        meio_transporte [Bicicleta]  meio_transporte [Carona]  \
# count                  8293.000000               8293.000000
# mean                      0.010250                  0.057639
# std                       0.100726                  0.233074
# min                       0.000000                  0.000000
# 25%                       0.000000                  0.000000
# 50%                       0.000000                  0.000000
# 75%                       0.000000                  0.000000
# max                       1.000000                  1.000000
#
#        meio_transporte [Fretado/van]  meio_transporte [Metrô]  \
# count                    8293.000000              8293.000000
# mean                        0.048716                 0.286507
# std                         0.215286                 0.452156
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 1.000000
# max                         1.000000                 1.000000
#
#        meio_transporte [Ônibus da UFABC]  \
# count                        8293.000000
# mean                            0.521283
# std                             0.499577
# min                             0.000000
# 25%                             0.000000
# 50%                             1.000000
# 75%                             1.000000
# max                             1.000000
#
#        meio_transporte [Transporte particular (carro)]  \
# count                                      8293.000000
# mean                                          0.284939
# std                                           0.451413
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           1.000000
# max                                           1.000000
#
#        meio_transporte [Transporte particular (moto)]  \
# count                                     8293.000000
# mean                                         0.028578
# std                                          0.166628
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        meio_transporte [Uber/taxi]  meio_transporte [Trem]  \
# count                  8293.000000             8293.000000
# mean                      0.030508                0.380562
# std                       0.171990                0.485554
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                1.000000
# max                       1.000000                1.000000
#
#        meio_transporte [Trólebus/ônibus - exceto ônibus da UFABC]  \
# count                                        8293.000000
# mean                                            0.372483
# std                                             0.483495
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        meio_transporte [Prefiro não responder]  tempo_medio_chegada_na_ufabc  \
# count                              8666.000000                   9929.000000
# mean                                  0.043042                     70.374056
# std                                   0.202963                     46.796808
# min                                   0.000000                     -1.000000
# 25%                                   0.000000                     30.000000
# 50%                                   0.000000                     60.000000
# 75%                                   0.000000                    120.000000
# max                                   1.000000                    150.000000
#
#        atividade_extraclasse [Não participo de atividades extraclasse relacionadas à UFABC]  \
# count                                        9263.000000
# mean                                            0.677966
# std                                             0.467281
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        atividade_extraclasse [AIESEC]  \
# count                     2983.000000
# mean                         0.023131
# std                          0.150345
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          1.000000
#
#        atividade_extraclasse [Atividades culturais]  \
# count                                   2983.000000
# mean                                       0.136440
# std                                        0.343313
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        atividade_extraclasse [Atividades de extensão]  \
# count                                     2983.000000
# mean                                         0.231646
# std                                          0.421955
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        atividade_extraclasse [Atividades esportivas]  \
# count                                    2983.000000
# mean                                        0.160912
# std                                         0.367511
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        atividade_extraclasse [AXIS  Atlética UFABC/CAAP]  \
# count                                        2983.000000
# mean                                            0.076768
# std                                             0.266268
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Coletivos de cunho religioso]  \
# count                                        2983.000000
# mean                                            0.032853
# std                                             0.178281
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Coletivos relacionados ao ativismo político]  \
# count                                        2983.000000
# mean                                            0.056654
# std                                             0.231220
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Coletivos relacionados ao empreendedorismo]  \
# count                                        2983.000000
# mean                                            0.012404
# std                                             0.110697
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Cursos de idiomas]  \
# count                                2983.000000
# mean                                    0.083808
# std                                     0.277146
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        atividade_extraclasse [DCE/Diretório Acadêmico/Centros Acadêmicos.]  \
# count                                        2983.000000
# mean                                            0.087831
# std                                             0.283096
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Empresas júniores]  \
# count                                2983.000000
# mean                                    0.031847
# std                                     0.175622
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        atividade_extraclasse [ENACTUS UFABC]  \
# count                            2983.000000
# mean                                0.027489
# std                                 0.163531
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        atividade_extraclasse [Coletivos LGBTQ+]  \
# count                               2983.000000
# mean                                   0.018103
# std                                    0.133345
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        atividade_extraclasse [Coletivos feministas]  \
# count                                   2983.000000
# mean                                       0.035535
# std                                        0.185158
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        atividade_extraclasse [Coletivos étnico-raciais]  \
# count                                       2983.000000
# mean                                           0.015085
# std                                            0.121913
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        atividade_extraclasse [GPDA UFABC]  \
# count                         2983.000000
# mean                             0.037211
# std                              0.189310
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        atividade_extraclasse [Infanteria UFABC]  \
# count                               2983.000000
# mean                                   0.038887
# std                                    0.193358
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        atividade_extraclasse [Ramo Estudantil IEEE da UFABC]  \
# count                                        2983.000000
# mean                                            0.061012
# std                                             0.239393
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [Representação discente (ConsUni, ConsEPE, Comissões, etc)]  \
# count                                        2983.000000
# mean                                            0.026819
# std                                             0.161580
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        atividade_extraclasse [UFABC Cheer]  \
# count                          2983.000000
# mean                              0.027824
# std                               0.164497
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        atividade_extraclasse [Outras atividades extraclasse (não listadas acima)]  \
# count                                        2983.000000
# mean                                            0.328528
# std                                             0.469757
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        atividade_extraclasse [Prefiro não responder]  \
# count                                    3649.000000
# mean                                        0.182516
# std                                         0.386322
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        nivel_conhecimento_idioma [Alemão]  \
# count                         9929.000000
# mean                             0.112902
# std                              0.507442
# min                             -1.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              4.000000
#
#        nivel_conhecimento_idioma [Espanhol]  \
# count                           9929.000000
# mean                               0.112902
# std                                0.507442
# min                               -1.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                4.000000
#
#        nivel_conhecimento_idioma [Francês]  \
# count                          9929.000000
# mean                              0.112902
# std                               0.507442
# min                              -1.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               4.000000
#
#        nivel_conhecimento_idioma [Inglês]  \
# count                         9929.000000
# mean                             0.112902
# std                              0.507442
# min                             -1.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              4.000000
#
#        nivel_conhecimento_idioma [Italiano]  \
# count                           9929.000000
# mean                               0.112902
# std                                0.507442
# min                               -1.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                4.000000
#
#        nivel_conhecimento_idioma [Japonês]  \
# count                          9929.000000
# mean                              0.112902
# std                               0.507442
# min                              -1.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               4.000000
#
#        nivel_conhecimento_idioma [Libras]  dificuldades [Nenhuma]  \
# count                         9929.000000             9362.000000
# mean                             0.112902                0.118351
# std                              0.507442                0.323040
# min                             -1.000000                0.000000
# 25%                              0.000000                0.000000
# 50%                              0.000000                0.000000
# 75%                              0.000000                0.000000
# max                              4.000000                1.000000
#
#        dificuldades [Acessibilidade nas dependências da UFABC]  \
# count                                        8254.000000
# mean                                            0.058032
# std                                             0.233819
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        dificuldades [Assuntos familiares/pessoais]  \
# count                                  8254.000000
# mean                                      0.302399
# std                                       0.459325
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       1.000000
# max                                       1.000000
#
#        dificuldades [Déficit de formação acadêmica básica]  \
# count                                        8254.000000
# mean                                            0.209474
# std                                             0.406958
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        dificuldades [Didática dos docentes]  \
# count                           8254.000000
# mean                               0.396656
# std                                0.489233
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                1.000000
# max                                1.000000
#
#        dificuldades [Discriminações e preconceitos]  \
# count                                   8254.000000
# mean                                       0.007754
# std                                        0.087719
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        dificuldades [Falta de disciplina/hábito de estudo]  \
# count                                        8254.000000
# mean                                            0.467531
# std                                             0.498975
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        dificuldades [Problemas de saúde/psicológicos]  \
# count                                     8254.000000
# mean                                         0.304943
# std                                          0.460411
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        dificuldades [Questões financeiras]  \
# count                          8254.000000
# mean                              0.202205
# std                               0.401669
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        dificuldades [Questões profissionais]  \
# count                            8254.000000
# mean                                0.290526
# std                                 0.454033
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 1.000000
# max                                 1.000000
#
#        dificuldades [Prefiro não responder]  \
# count                           8821.000000
# mean                               0.064278
# std                                0.245262
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        dificuldades_emocionais [Nenhuma]  dificuldades_emocionais [Ansiedade]  \
# count                        9299.000000                          7594.000000
# mean                            0.183353                             0.670003
# std                             0.386977                             0.470243
# min                             0.000000                             0.000000
# 25%                             0.000000                             0.000000
# 50%                             0.000000                             1.000000
# 75%                             0.000000                             1.000000
# max                             1.000000                             1.000000
#
#        dificuldades_emocionais [Desânimo, falta de vontade de fazer as coisas]  \
# count                                        7594.000000
# mean                                            0.706610
# std                                             0.455345
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        dificuldades_emocionais [Distúrbios alimentares]  \
# count                                       7594.000000
# mean                                           0.044245
# std                                            0.205654
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        dificuldades_emocionais [Ideia de morte (Pensamentos homicidas, medo da morte, etc)]  \
# count                                        7594.000000
# mean                                            0.026073
# std                                             0.159364
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        dificuldades_emocionais [Medo/pânico]  \
# count                            7594.000000
# mean                                0.048064
# std                                 0.213916
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        dificuldades_emocionais [Pensamento suicida]  \
# count                                   7594.000000
# mean                                       0.055439
# std                                        0.228849
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        dificuldades_emocionais [Sensação de desamparo/desespero/desesperança]  \
# count                                        7594.000000
# mean                                            0.218067
# std                                             0.412960
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        dificuldades_emocionais [Sensação de desatenção/desorientação/confusão mental]  \
# count                                        7594.000000
# mean                                            0.166579
# std                                             0.372624
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        dificuldades_emocionais [Sentimento de solidão]  \
# count                                      7594.000000
# mean                                          0.159600
# std                                           0.366259
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        dificuldades_emocionais [Timidez excessiva]  \
# count                                  7594.000000
# mean                                      0.081380
# std                                       0.273436
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        dificuldades_emocionais [Tristeza persistente]  \
# count                                     7594.000000
# mean                                         0.097840
# std                                          0.297118
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        dificuldades_emocionais [Prefiro não responder]  \
# count                                      8224.000000
# mean                                          0.076605
# std                                           0.265980
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        preconceito_discriminacao [Não]  \
# count                      9287.000000
# mean                          0.858081
# std                           0.348986
# min                           0.000000
# 25%                           1.000000
# 50%                           1.000000
# 75%                           1.000000
# max                           1.000000
#
#        preconceito_discriminacao [Sim, pela instituição de ensino em que cursei o ensino médio]  \
# count                                        1318.000000
# mean                                            0.066009
# std                                             0.248392
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha aparência física]  \
# count                                        1318.000000
# mean                                            0.175266
# std                                             0.380338
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha condição socioeconômica]  \
# count                                        1318.000000
# mean                                            0.142640
# std                                             0.349838
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha etnia/raça]  \
# count                                        1318.000000
# mean                                            0.135812
# std                                             0.342719
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha idade]  \
# count                                        1318.000000
# mean                                            0.094841
# std                                             0.293106
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha identidade de gênero]  \
# count                                        1318.000000
# mean                                            0.047041
# std                                             0.211807
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pela minha orientação sexual/afetiva]  \
# count                                        1318.000000
# mean                                            0.099393
# std                                             0.299303
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pelo meu local de moradia]  \
# count                                        1318.000000
# mean                                            0.062215
# std                                             0.241638
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pelo meu local de nascimento/origem]  \
# count                                        1318.000000
# mean                                            0.045524
# std                                             0.208528
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        preconceito_discriminacao [Sim, pelo meu posicionamento político-ideológico]  \
# ...
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        pretende_pos_grad [Sim  em outra instituição internacional  \
# count                                        9929.000000
# mean                                            0.061839
# std                                             0.240875
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        pretende_pos_grad [Sim  em outra instituição nacional  \
# count                                        9929.000000
# mean                                            0.065666
# std                                             0.247710
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        pretende_pos_grad [Sim  na UFABC  fonte_de_sustento [-1  \
# count                        9929.000000            9929.000000
# mean                            0.191157               0.107463
# std                             0.393232               0.309717
# min                             0.000000               0.000000
# 25%                             0.000000               0.000000
# 50%                             0.000000               0.000000
# 75%                             0.000000               0.000000
# max                             1.000000               1.000000
#
#        fonte_de_sustento [Auxílio do Governo (Pensão, Bolsa Família, etc)  \
# count                                        9929.000000
# mean                                            0.011784
# std                                             0.107917
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        fonte_de_sustento [Auxílio por caridade  \
# count                              9929.000000
# mean                                  0.001511
# std                                   0.038841
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        fonte_de_sustento [Bolsa(s) socioeconômica(s) e/ou acadêmica(s) (UFABC, PIBIC, PIBID, etc)  \
# count                                        9929.000000
# mean                                            0.057307
# std                                             0.232440
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        fonte_de_sustento [Economias, poupança e rendimentos  \
# count                                        9929.000000
# mean                                            0.010575
# std                                             0.102295
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        fonte_de_sustento [Estágio  fonte_de_sustento [Família  \
# count                 9929.000000                 9929.000000
# mean                     0.143015                    0.345050
# std                      0.350106                    0.475408
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    1.000000
# max                      1.000000                    1.000000
#
#        fonte_de_sustento [Nenhuma das anteriores  \
# count                                9929.000000
# mean                                    0.017323
# std                                     0.130478
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        fonte_de_sustento [Trabalho formal (exceto estágio)  \
# count                                        9929.000000
# mean                                            0.267096
# std                                             0.442465
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        fonte_de_sustento [Trabalho informal  \
# count                           9929.000000
# mean                               0.038876
# std                                0.193309
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        tipo_de_vinculo_atividade_remunerada [-1  \
# count                               9929.000000
# mean                                   0.004834
# std                                    0.069365
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Assalariado(a) formal  \
# count                                        9929.000000
# mean                                            0.198207
# std                                             0.398669
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Assalariado(a) informal  \
# count                                        9929.000000
# mean                                            0.017222
# std                                             0.130105
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Estágio  \
# count                                    9929.000000
# mean                                        0.179273
# std                                         0.383600
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Profissional liberal ou autônomo  \
# count                                        9929.000000
# mean                                            0.018834
# std                                             0.135944
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Proprietário(a) de empresa  \
# count                                        9929.000000
# mean                                            0.007956
# std                                             0.088848
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Servidor(a) público(a)  \
# count                                        9929.000000
# mean                                            0.031121
# std                                             0.173653
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        tipo_de_vinculo_atividade_remunerada [Trabalho informal    setor [-1  \
# count                                        9929.000000        9929.000000
# mean                                            0.024877           0.009064
# std                                             0.155757           0.094779
# min                                             0.000000           0.000000
# 25%                                             0.000000           0.000000
# 50%                                             0.000000           0.000000
# 75%                                             0.000000           0.000000
# max                                             1.000000           1.000000
#
#        setor [Comércio  setor [Cultura e Esporte  setor [Educação  \
# count      9929.000000               9929.000000      9929.000000
# mean          0.046027                  0.007050         0.050055
# std           0.209554                  0.083672         0.218070
# min           0.000000                  0.000000         0.000000
# 25%           0.000000                  0.000000         0.000000
# 50%           0.000000                  0.000000         0.000000
# 75%           0.000000                  0.000000         0.000000
# max           1.000000                  1.000000         1.000000
#
#        setor [Indústria  setor [Nenhuma das anteriores  setor [Saúde  \
# count       9929.000000                    9929.000000   9929.000000
# mean           0.108873                       0.081176      0.013697
# std            0.311495                       0.273120      0.116237
# min            0.000000                       0.000000      0.000000
# 25%            0.000000                       0.000000      0.000000
# 50%            0.000000                       0.000000      0.000000
# 75%            0.000000                       0.000000      0.000000
# max            1.000000                       1.000000      1.000000
#
#        setor [Serviços  tipo_moradia [-1  \
# count      9929.000000       9929.000000
# mean          0.166381          0.102931
# std           0.372441          0.303884
# min           0.000000          0.000000
# 25%           0.000000          0.000000
# 50%           0.000000          0.000000
# 75%           0.000000          0.000000
# max           1.000000          1.000000
#
#        tipo_moradia [Casa/Apartamento alugado  \
# count                             9929.000000
# mean                                 0.218955
# std                                  0.413559
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        tipo_moradia [Casa/Apartamento cedido  \
# count                            9929.000000
# mean                                0.072011
# std                                 0.258520
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        tipo_moradia [Casa/Apartamento próprio (financiado ou já quitado)  \
# count                                        9929.000000
# mean                                            0.519690
# std                                             0.499637
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        tipo_moradia [Moradia irregular/ocupação  \
# count                               9929.000000
# mean                                   0.004633
# std                                    0.067911
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        tipo_moradia [Pensão/Hotel/Pensionato  tipo_moradia [República
# count                            9929.000000              9929.000000
# mean                                0.011582                 0.070198
# std                                 0.107001                 0.255494
# min                                 0.000000                 0.000000
# 25%                                 0.000000                 0.000000
# 50%                                 0.000000                 0.000000
# 75%                                 0.000000                 0.000000
# max                                 1.000000                 1.000000

# %% [markdown]
# ## Data Pruning
# <p>Em teoria, não seria necessária a retirada de nenhum dado
# (não foi identificado a existência de ruido ou outliers negativos),<br>
# mas alguns dados seriam impossíveis de serem coletados de ingressantes, então
# serão descartados </p>

# %%
columns = {}
for c in base_2018_encoded.columns:
    c = c.split('[')[0]
    if c in columns:
        columns[c]+=1
    else:
        columns[c]=1

# %%
print('numero de colunas:',len(columns))
list(columns.keys())
# Out:
# numero de colunas: 66
# ['ano_ingresso',
#  'frequentou_cursinho',
#  'escolaridade_pai',
#  'escolaridade_mae',
#  'forma_ingresso ',
#  'idade',
#  'sexo_biologico',
#  'nmr_filhos',
#  'meio_transporte ',
#  'tempo_medio_chegada_na_ufabc',
#  'atividade_extraclasse ',
#  'nivel_conhecimento_idioma ',
#  'dificuldades ',
#  'dificuldades_emocionais ',
#  'preconceito_discriminacao ',
#  'assedio ',
#  'fumante',
#  'consome_bebidas_alcoolicas',
#  'doenca_cronica ',
#  'favoravel_cotas ',
#  'pdv_diversidade ',
#  'pos-bct_pretende ',
#  'pos-bct_matriculado ',
#  'pos-bch_pretende ',
#  'pos-bch_matriculado ',
#  'deseja_solicitar_transf_interna',
#  'possui_reprovacoes',
#  'trancamento_matricula',
#  'motivo_trancamento_matricula ',
#  'mobilidade_academica',
#  'programa_desenv_acad ',
#  'CR',
#  'CA',
#  'horas_semanais_na_ufabc',
#  'obj_pos_conclusao ',
#  'nota_infraestrutura_sa ',
#  'nota_infraestrutura_sbc ',
#  'nota ',
#  'renda_familiar_mensal',
#  'qtd_pessoas_familia',
#  'principal_mantedor_familia ',
#  'salario_mensal',
#  'atividade_remunerada',
#  'programa_assist_estudantil ',
#  'frequencia_ru',
#  'valor_gasto_alimentacao_interna',
#  'nota_questionario',
#  'como_conheceu ',
#  'motivo_escolha ',
#  'estado_civil ',
#  'identidade_genero ',
#  'orientacao_sexual ',
#  'cor/raca ',
#  'onde_reside ',
#  'regiao_sp_reside ',
#  'consome_subst_psicoativas ',
#  'dieta_alimentar ',
#  'religiao ',
#  'campus_atual ',
#  'turno ',
#  'bacharel_interdisciplinar ',
#  'pretende_pos_grad ',
#  'fonte_de_sustento ',
#  'tipo_de_vinculo_atividade_remunerada ',
#  'setor ',
#  'tipo_moradia ']

# %%
remover =['possui_reprovacoes',
          'trancamento_matricula',
          'motivo_trancamento_matricula ',
          'mobilidade_academica',
          'programa_desenv_acad ',
          'ano_ingresso',
          'pos-bct_matriculado',
          'pos-bct_matriculado',
          'nota']

# %%
base_2018_encoded.filter(regex='frequencia_ru').head()
# Out:
#    frequencia_ru
# 0           -1.0
# 1            2.0
# 2            4.0
# 3            3.0
# 4            2.0

# %%
for r in remover:
    contem = []
    for c in base_2018_encoded.columns:
        if r in c:
            contem.append(c)
    base_2018_encoded.drop(contem,axis=1,inplace=True)

# %%
columns = {}
for c in base_2018_encoded.columns:
    c = c.split('[')[0]
    if c in columns:
        columns[c]+=1
    else:
        columns[c]=1

# %%
print('numero de colunas:',len(columns))
list(columns.keys())
# Out:
# numero de colunas: 55
# ['frequentou_cursinho',
#  'escolaridade_pai',
#  'escolaridade_mae',
#  'forma_ingresso ',
#  'idade',
#  'sexo_biologico',
#  'nmr_filhos',
#  'meio_transporte ',
#  'tempo_medio_chegada_na_ufabc',
#  'atividade_extraclasse ',
#  'nivel_conhecimento_idioma ',
#  'dificuldades ',
#  'dificuldades_emocionais ',
#  'preconceito_discriminacao ',
#  'assedio ',
#  'fumante',
#  'consome_bebidas_alcoolicas',
#  'doenca_cronica ',
#  'favoravel_cotas ',
#  'pdv_diversidade ',
#  'pos-bct_pretende ',
#  'pos-bch_pretende ',
#  'pos-bch_matriculado ',
#  'deseja_solicitar_transf_interna',
#  'CR',
#  'CA',
#  'horas_semanais_na_ufabc',
#  'obj_pos_conclusao ',
#  'renda_familiar_mensal',
#  'qtd_pessoas_familia',
#  'principal_mantedor_familia ',
#  'salario_mensal',
#  'atividade_remunerada',
#  'programa_assist_estudantil ',
#  'frequencia_ru',
#  'valor_gasto_alimentacao_interna',
#  'como_conheceu ',
#  'motivo_escolha ',
#  'estado_civil ',
#  'identidade_genero ',
#  'orientacao_sexual ',
#  'cor/raca ',
#  'onde_reside ',
#  'regiao_sp_reside ',
#  'consome_subst_psicoativas ',
#  'dieta_alimentar ',
#  'religiao ',
#  'campus_atual ',
#  'turno ',
#  'bacharel_interdisciplinar ',
#  'pretende_pos_grad ',
#  'fonte_de_sustento ',
#  'tipo_de_vinculo_atividade_remunerada ',
#  'setor ',
#  'tipo_moradia ']

# %% [markdown]
# # Classificador

# %% [markdown]
# #### Para classificar o CR iremos excluir todos que não possuem CR registrado

# %%
base_2018_encoded.dropna(subset=['CR'],inplace=True)

# %% [markdown]
# #### Separando target

# %%
X = base_2018_encoded.drop(['CR','CA'],axis=1)
y = base_2018_encoded['CR']

# %% [markdown]
# ### Análise do Target

# %%
print('Media do CR:','{0:.2}'.format(y.mean()))
print('Desvio padrão:','{0:.2}'.format(y.std()))
fig,axs=plt.subplots(1,1)
axs.set_title('Histograma CR')
axs.set_ylabel('Volume')
axs.set_xlabel('CR')
y.hist(ax=axs)
fig.savefig('../output/figures/histograma_cr.png')
fig.show()
# Out:
# Media do CR: 2.3
# Desvio padrão: 0.76
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print('Distribuição do target:')
print((y<2).map({True:'Abaixo de 2',False:'Acima de 2'}).value_counts())
fig,axs=plt.subplots(1,1)
axs.set_title('Distribuição dos discentes')
axs.set_ylabel('Volume')
(y<2).map({True:'Abaixo de 2',False:'Acima de 2'}).value_counts().plot(ax=axs,kind='bar',rot=0)
fig.savefig('../output/figures/distribuicao_classes.png')
fig.show()
# Out:
# Distribuição do target:
# Acima de 2     6029
# Abaixo de 2    2540
# Name: CR, dtype: int64
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# #### Preenchendo valores nulos com a média

# %%
X.fillna(base_2018_encoded.mean(),inplace=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
## Garantindo indices resetados
X_train.reset_index(drop=True,inplace=True)
y_train.reset_index(drop=True,inplace=True)


X_test.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

# %%
y_label = y<2

# %%
y_label_train = y_train<2
y_label_test = y_test<2

# %%
y_label.value_counts()
# Out:
# False    6029
# True     2540
# Name: CR, dtype: int64

# %% [markdown]
# #### Como a base está desbalanceada, sera feito o oversample da classe alvo

# %%
sm = SMOTE(sampling_strategy='minority',random_state=12)

# %%
X_train_os, y_label_train_os = sm.fit_resample(X_train, y_label_train)

# %%
y_label_train_os.value_counts()
# Out:
# False    4552
# True     4552
# Name: CR, dtype: int64

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(50, 300, num = 10)]
# Minimum number of samples for split
min_samples_split = range(2,10)
max_depth.append(None)
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split':min_samples_split}

rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(
    estimator = rf,
    param_distributions = random_grid,
    n_iter = 50,
    verbose=True,
    n_jobs = 3,
    cv = 5)

# %%
rf_random.fit(X_train_os, y_label_train_os)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=50,
#                    n_jobs=3,
#                    param_distributions={'max_depth': [50, 77, 105, 133, 161,
#                                                       188, 216, 244, 272, 300,
#                                                       None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_split': range(2, 10),
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    verbose=True)

# %%
rf_random.best_score_
# Out:
# 0.7831889252976568

# %%
best_rf = rf_random.best_estimator_

# %%
best_rf.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier(max_depth=50, max_features='sqrt', n_estimators=1000)>

# %%
best_rf.fit(X_train_os,y_label_train_os)
# Out:
# RandomForestClassifier(max_depth=50, max_features='sqrt', n_estimators=1000)

# %%
joblib.dump(best_rf,'../models/random_forest_classifier_cr_prediction_entry_data.pkl')
# Out:
# ['../models/random_forest_classifier_cr_prediction_entry_data.pkl']

# %%
best_rf = joblib.load('../models/random_forest_classifier_cr_prediction_entry_data.pkl')

# %%
best_rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 50,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 1000,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
best_rf.fit(X_train_os,y_label_train_os)
# Out:
# RandomForestClassifier(max_depth=50, max_features='sqrt', n_estimators=1000)

# %%
pb = best_rf.predict_proba(X_test)
probability =[]
for p in pb:
    probability.append(p[1])

# %%
y_score = best_rf.predict(X_test)

# %%
accuracy_score(y_label_test,y_score)
# Out:
# 0.7102193187120859

# %% [markdown]
# ## Precision vs. Recall

# %%
best_rf.predict_proba(X_test)[:,1].argmin()
# Out:
# 141

# %%
disp = plot_precision_recall_curve(best_rf, X_test, y_label_test)
disp.ax_.set_title('2-class Precision-Recall curve')
disp.ax_.set_ylim(0,1.0)
disp.ax_.set_xlim(.01,1)
disp.ax_.get_figure().savefig('../output/figures/precision-recall-curve.png')

# %%
predict_p = [x[1] for x in best_rf.predict_proba(X_test)]
fpr,tpr, thresholds = roc_curve(y_label_test,predict_p)
aux_dict = {
    'fpr':fpr,
    'tpr':tpr,
    'thresholds': thresholds
}
df_scores = pd.DataFrame(aux_dict)

# %%
recalls = []
precisions = []
for i in thresholds:
    predictions_aux = predict_p>=i
    true_p = (predictions_aux==True) & (y_label_test==True)
    if(True in true_p.value_counts().index):
        tp = true_p.value_counts()[True]
    else:
        tp=0
    #print(tp)
    false_n = (predictions_aux==False) & (y_label_test==True)
    if(True in false_n.value_counts().index):
        fn = false_n.value_counts()[True]
    else:
        fn = 0
    false_p = (predictions_aux==True) & (y_label_test==False)
    if(True in false_p.value_counts().index):
        fp = false_p.value_counts()[True]
    else:
        fp = 0
    #print(fn)
    recalls.append(tp/(tp+fn))
    if((tp+fp)==0):
        precisions.append(0)
    else:
        precisions.append(tp/(tp+fp))
df_scores['recalls'] = recalls
df_scores['precisions'] = precisions

# %%
df_scores.loc[(df_scores['recalls']>0.75) & (df_scores['recalls']<=0.8)]
# Out:
#           fpr       tpr  thresholds   recalls  precisions
# 289  0.392011  0.750751    0.313000  0.750751    0.463392
# 290  0.392011  0.752252    0.312367  0.752252    0.463889
# 291  0.394719  0.756757    0.312000  0.756757    0.463661
# 292  0.400135  0.756757    0.311000  0.756757    0.460274
# 293  0.403521  0.759760    0.310000  0.759760    0.459165
# 294  0.404198  0.761261    0.309000  0.761261    0.459239
# 295  0.406229  0.765766    0.308000  0.765766    0.459459
# 296  0.407583  0.767267    0.307000  0.767267    0.459119
# 297  0.412322  0.767267    0.306000  0.767267    0.456250
# 298  0.412999  0.771772    0.305000  0.771772    0.457295
# 299  0.416385  0.773273    0.304000  0.773273    0.455752
# 300  0.418416  0.774775    0.303000  0.774775    0.455026
# 301  0.421801  0.774775    0.302000  0.774775    0.453029
# 302  0.422478  0.774775    0.301000  0.774775    0.452632
# 303  0.425186  0.774775    0.300000  0.774775    0.451049
# 304  0.429248  0.782282    0.299000  0.782282    0.451082
# 305  0.430603  0.786787    0.298000  0.786787    0.451724
# 306  0.433311  0.788288    0.297000  0.788288    0.450644
# 307  0.436019  0.792793    0.296000  0.792793    0.450512
# 308  0.438050  0.795796    0.295000  0.795796    0.450297
# 309  0.441435  0.797297    0.294000  0.797297    0.448859
# 310  0.443466  0.798799    0.293000  0.798799    0.448189

# %%
def predict_with_th(classificator,threshold,X):
    predictions_p = classificator.predict_proba(X)
    predictions_p_p = [x[1] for x in predictions_p]
    return [x>=threshold for x in predictions_p_p]

# %%
predictions_with_th = predict_with_th(best_rf,0.290218,X_test)

# %%
print("ROC-Auc do modelo implementando o Threshold para Recall 0.8")
print("Acurácia: {0:.2%}".format(accuracy_score(y_label_test,predictions_with_th)))
print("Recall: {0:.2%}".format(recall_score(y_label_test,predictions_with_th)))
print("Precision: {0:.2%}".format(precision_score(y_label_test,predictions_with_th)))
print("ROC Auc: {0:.2%}".format(roc_auc_score(y_label_test,predictions_with_th)))
# Out:
# ROC-Auc do modelo implementando o Threshold para Recall 0.8
# Acurácia: 63.00%
# Recall: 80.48%
# Precision: 44.70%
# ROC Auc: 67.80%

# %% [markdown]
# ## Roc Curve

# %%
def plot_roc_curve(fpr,tpr, thresholds):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % auc(fpr, tpr))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    
    plt.title('Roc Curve Analysis')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc="center right")
    
    # create the axis of thresholds (scores)
    ax2 = plt.gca().twinx()
    ax2.plot(fpr, thresholds, markeredgecolor='r',linestyle='dashed', color='r')
    ax2.set_ylabel('Threshold',color='r')
    ax2.set_ylim([thresholds[-1],thresholds[0]])
    ax2.set_xlim([fpr[0],fpr[-1]])
    
    
    
    plt.savefig('../output/figures/roc_and_threshold.png')
    plt.show()
    plt.close()

# %%
predict_p = [x[1] for x in best_rf.predict_proba(X_test)]
fpr,tpr, thresholds = roc_curve(y_label_test,predict_p)

# %%
plot_roc_curve(fpr,tpr,thresholds)

# %% [markdown]
# # Compiling Results

# %%
results_df = pd.DataFrame(best_rf.predict_proba(X_test),columns=best_rf.classes_)
results_df['Predictions'] = best_rf.predict(X_test)
results_df['Real class'] = y_label_test.tolist()
results_df['Correct'] = results_df['Predictions']==results_df['Real class']
results_df['True Positive'] = (results_df['Predictions']==True) & (results_df['Real class']==True)
results_df['False Negative'] = (results_df['Predictions']==False) & (results_df['Real class']==True)

# %%
results_df
# Out:
#       False   True  Predictions  Real class  Correct  True Positive  \
# 0     0.610  0.390        False       False     True          False
# 1     0.732  0.268        False        True    False          False
# 2     0.626  0.374        False        True    False          False
# 3     0.764  0.236        False       False     True          False
# 4     0.591  0.409        False        True    False          False
# ...     ...    ...          ...         ...      ...            ...
# 2138  0.661  0.339        False        True    False          False
# 2139  0.598  0.402        False       False     True          False
# 2140  0.826  0.174        False       False     True          False
# 2141  0.434  0.566         True       False    False          False
# 2142  0.487  0.513         True       False    False          False
#
#       False Negative
# 0              False
# 1               True
# 2               True
# 3              False
# 4               True
# ...              ...
# 2138            True
# 2139           False
# 2140           False
# 2141           False
# 2142           False
#
# [2143 rows x 7 columns]

# %% [markdown]
# # Analisando as Features

# %%
importances = best_rf.feature_importances_
dict_aux = {
    'name':X_train.columns.tolist(),
    'importance':importances
}
df_importancias = pd.DataFrame(dict_aux).sort_values('importance',ascending=False).reset_index().drop('index',axis=1)

# %%
plt.plot(df_importancias['importance'].head(10))

# %%
df_importancias.head(20)
# Out:
#                                                  name  importance
# 0                                               idade    0.027190
# 1                 forma_ingresso [Ampla concorrência]    0.023800
# 2                             horas_semanais_na_ufabc    0.013382
# 3              forma_ingresso [Transferência externa]    0.011492
# 4   forma_ingresso [Reserva de vagas (refugiado ou...    0.011455
# 5   forma_ingresso [PEC-G/Transferência Ex Officio...    0.010720
# 6                               renda_familiar_mensal    0.010455
# 7              forma_ingresso [Prefiro não responder]    0.010095
# 8   campus_atual [Somente no campus São Bernardo d...    0.009676
# 9        pos-bct_pretende [Bacharelado em Matemática]    0.009626
# 10                                     salario_mensal    0.009608
# 11           pos-bct_pretende [Prefiro não responder]    0.009464
# 12                                qtd_pessoas_familia    0.009145
# 13                          pos-bct_pretende [Nenhum]    0.009077
# 14  forma_ingresso [Reserva de vagas (pessoa com d...    0.008637
# 15                                      frequencia_ru    0.008561
# 16                               atividade_remunerada    0.008546
# 17  pos-bct_pretende [Licenciatura em Ciências Bio...    0.008409
# 18      pos-bct_pretende [Licenciatura em Matemática]    0.008400
# 19                                    turno [Matutino    0.007948

# %% [markdown]
# # Shap Value

# %%
importances = best_rf.feature_importances_[:20]
indices = np.argsort(importances)

features = X_train.columns
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
rf_shap_values = shap.TreeExplainer(best_rf).shap_values(X_train)

# %%
shap.summary_plot(rf_shap_values[1], X_test)

# %%
#X_test_sample = X_test.sample(n=500)

# %%
#k_shap = shap.KernelExplainer(best_rf.predict,X_test_sample)

# %%
#k_shap_values = k_shap.shap_values(X_test_sample)

# %%
# enum={}
# reverse_enum={}
# for i in range(0,len(X_test_sample.columns)):
#     enum[X_test_sample.columns[i]]=str(i)
#     reverse_enum[str(i)]=X_test_sample.columns[i]

# %%
# shap.summary_plot(k_shap_values, X_test_sample)
